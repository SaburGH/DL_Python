# %% [markdown]
# <a href="https://colab.research.google.com/github/SaburGH/DL_Python/blob/master/session_1_image_Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image read, write and show

# %% [markdown]
# Python supports very powerful tools when comes to image processing. Let’s see how to process the images using different libraries like
#
# ***
#  ### ImageIO,
#  ### OpenCV,
#  ### Matplotlib,
#  ### PIL,
#  etc.
#  ***

# %% [markdown]
# Reading images in Python
# Last Updated : 13 Feb, 2023
# Python supports very powerful tools when comes to image processing. Let’s see how to process the images using different libraries like ImageIO, OpenCV, Matplotlib, PIL, etc.
#
# Using ImageIO : Imageio is a Python library that provides an easy interface to read and write a wide range of image data, including animated images, video, volumetric data, and scientific formats. It is cross-platform, runs on Python 3.7+, and is easy to install. It is the recommended alternative to scipy.misc.imread and is used internally by libraries like scikit-image to load images.

# %% [markdown]
# ## 1. Read an image as input and write in as an another file as output (image input output ImageIO)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Python program to read an write an image

import imageio as iio
import matplotlib.pyplot as plt
# read an image
#img = iio.imread("pexels-maxandrey-1366630.jpg")
img = iio.imread("/content/drive/MyDrive/Colab_nb/RGB_channels_separation.png")
plt.imshow(img)
# write it in a new format
iio.imwrite("/content/drive/MyDrive/Colab_nb/RGB_channels_separation_new.png", img)
# Out:
# <ipython-input-56-407836363d07>:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/drive/MyDrive/Colab_nb/RGB_channels_separation.png")

# %% [markdown]
# #### After write load the new file

# %%
img1 = iio.imread("/content/drive/MyDrive/Colab_nb/RGB_channels_separation_new.png")
plt.imshow(img1)
# Out:
# <ipython-input-57-5632d554b7b5>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img1 = iio.imread("/content/drive/MyDrive/Colab_nb/RGB_channels_separation_new.png")

# %% [markdown]
# Using OpenCV : OpenCV (Open Source Computer Vision) is a computer vision library that contains various functions to perform operations on pictures or videos. It was originally developed by Intel but was later maintained by Willow Garage and is now maintained by Itseez. This library is cross-platform that is it is available on multiple programming languages such as Python, C++ etc.

# %% [markdown]
# ### 2. Open source computer vision (OpenCV)

# %%
#pip install opencv-python

# %% [markdown]
# #### Output image with a window name as 'image'

# %%
# Python program to read image using OpenCV

# importing OpenCV(cv2) module
import cv2
from google.colab.patches import cv2_imshow

# Save image in set directory
# Read RGB image
img = cv2.imread('/content/drive/MyDrive/Colab_nb/pexels-maxandrey-1366630.jpg')

# Output img with window name as 'image'
#cv2.imshow('image', img)
cv2_imshow(img) # For colab No need to pass a window name in cv2_imshow
# Maintain output window until
# user presses a key
#cv2.waitKey(0)

# Destroying present windows on screen
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=183x275>

# %%
# By ChatGpt

# # Importing OpenCV and Colab-specific display function
# import cv2
# from google.colab.patches import cv2_imshow

# # Read RGB image
# img = cv2.imread('/content/drive/MyDrive/Colab_nb/pexels-maxandrey-1366630.jpg')

# # Display image
# cv2_imshow(img)  # No need to pass a window name in cv2_imshow

# # Wait for a key press (this is not functional in Colab, but left for compatibility)
# cv2.waitKey(0)

# # Destroy all windows (also not functional in Colab, safe to omit or keep)
# cv2.destroyAllWindows()

# %% [markdown]
#
#
# Using MatplotLib : Matplotlib is an amazing visualization library in Python for 2D plots of arrays. Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack. It was introduced by John Hunter in the year 2002. Matplotlib comes with a wide variety of plots. Plots helps to understand trends, patterns, and to make correlations. They’re typically instruments for reasoning about quantitative information.

# %% [markdown]
# ### 3. Matplotlib format for image loading

# %%
# Python program to read
# image using matplotlib

# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read Images
#img = mpimg.imread('pexels-maxandrey-1366630.jpg')
img = mpimg.imread('/content/drive/MyDrive/Colab_nb/RGB_channels_separation_new.png')
# Output Images
plt.imshow(img)

# %% [markdown]
#
#
# Using PIL : PIL is the Python Imaging Library which provides the python interpreter with image editing capabilities. It was developed by Fredrik Lundh and several other contributors. Pillow is the friendly PIL fork and an easy to use library developed by Alex Clark and other contributors.

# %% [markdown]
# ## 4. Python imaging library (PIL) format for loading image

# %%
#pip install Pillow

# %%
#pip install --upgrade Pillow

# %%
# Python program to read
# image using PIL module

# importing PIL
from PIL import Image

# Read image
img = Image.open('/content/drive/MyDrive/Colab_nb/pexels-maxandrey-1366630.jpg')
#img = Image.open('RGB_channels_separation.png')
# Output Images
img.show()

# %%
# prints format of image
print(img.format)

# prints mode of image
print(img.mode)
# Out:
# JPEG
# RGB

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image using OpenCV
image = cv2.imread('/content/drive/MyDrive/Colab_nb/berry-1.jpg')

# Convert from BGR to RGB (Matplotlib uses RGB)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
plt.imshow(image)#_rgb)
plt.axis('off')  # Hide axes for better presentation
plt.show()
