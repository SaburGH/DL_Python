# %% [markdown]
# <a href="https://colab.research.google.com/github/SaburGH/DL_Python/blob/master/session_8_filtering_convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Filtering

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
arr = [
    [1,1,1],
    [1,1,1],
    [1,1,1]
    ]
kernel = np.array(arr, dtype=np.float32)
print(kernel)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
kernel = np.ones((3,3), np.float32)
print(kernel)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
kernel = kernel/9
print(kernel)
# Out:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %%
# using filter2d

img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/orange-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

kernel1 = np.ones((3,3),np.float32)
blur_img1 = cv2.filter2D(img,-1,kernel1) # when ddepth=-1, the output image will have the same depth as the source.

kernel2 = np.ones((11,11),np.float32)/121
blur_img2 = cv2.filter2D(img,-1,kernel2)

plt.figure(figsize=(15, 5))

plt.subplot(131),plt.imshow(img),plt.title('Original')
# plt.axis('off')
plt.subplot(132),plt.imshow(blur_img1),plt.title('Averaging 3X3')
# plt.axis('off')
plt.subplot(133),plt.imshow(blur_img2),plt.title('Averaging 7X7')
# plt.axis('off')
plt.show()

# %%
img.shape
# Out:
# (380, 380, 3)

# %%
blur_img2.shape
# Out:
# (380, 380, 3)

# %%
kernel1
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]], dtype=float32)

# %%
np.min(blur_img1)
# Out:
# np.uint8(0)

# %%
# averaging using cv2.blur(img, (k,k))

assert img is not None, "file could not be read, check with os.path.exists()"

blur_img1 = cv2.blur(img, (3, 3))

blur_img2 = cv2.blur(img, (7, 7))

plt.figure(figsize=(15, 5))

plt.subplot(131),plt.imshow(img),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(blur_img1),plt.title('Averaging 3X3')
plt.axis('off')
plt.subplot(133),plt.imshow(blur_img2),plt.title('Averaging 5X5')
plt.axis('off')
plt.show()
