# %% [markdown]
# <a href="https://colab.research.google.com/github/SaburGH/DL_Python/blob/master/session_10_high_pass_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/sudoku-1.jpg', cv2.IMREAD_GRAYSCALE)
img = cv2.imread('/content/sudoku-0.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img, cmap='gray')

# %%
sobel = cv2.Sobel(img, -1, 1, 0, 3)
plt.imshow(sobel, cmap='gray')
plt.title('Sobel')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1108.5), np.float64(-0.5))

# %%
sobel = cv2.Sobel(img, -1, 0, 1, 3)
plt.imshow(sobel, cmap='gray')
plt.title('Sobel')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1108.5), np.float64(-0.5))

# %%
# Sobel filtering

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#img = cv.imread('/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/sudoku-1.jpg', cv.IMREAD_GRAYSCALE)
img = cv2.imread('/content/sudoku-0.jpg', cv.IMREAD_GRAYSCALE)


sobel_x = cv.Sobel(img, -1, 1, 0, 3)
sobel_y = cv.Sobel(img, -1, 0, 1, 3)

plt.figure(figsize=(15,15))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.axis('off')


plt.subplot(1, 3, 2)
plt.imshow(sobel_x, cmap='gray')
plt.title('vertical sobel filter')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(sobel_y, cmap='gray')
plt.title('horizontal sobel filter')
plt.axis('off')

plt.show()

# %%
laplacian = cv.Laplacian(img, -1, ksize=3)
plt.imshow(laplacian, cmap='gray')
plt.title('laplacian')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1108.5), np.float64(-0.5))

# %%
# sobel vs laplacian

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#img = cv.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/sudoku-1.jpg', cv.IMREAD_GRAYSCALE)
img = cv2.imread('/content/sudoku-0.jpg',cv.IMREAD_GRAYSCALE)
sobel_x = cv.Sobel(img, -1, 1, 0, 3)
sobel_y = cv.Sobel(img, -1, 0, 1, 3)

laplacian = cv.Laplacian(img, -1)


plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.axis('off')


plt.subplot(2, 2, 2)
plt.imshow(sobel_x, cmap='gray')
plt.title('vertical sobel filter')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(sobel_y, cmap='gray')
plt.title('horizontal sobel filter')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(laplacian, cmap='gray')
plt.title('laplacian filter')
plt.axis('off')

plt.show()
