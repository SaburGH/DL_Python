# %% [markdown]
# <a href="https://colab.research.google.com/github/SaburGH/DL_Python/blob/master/session_3_color_space_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MatplotLib

# %%
# Matplotlib is usually pre-installed in Colab, but you can install it if needed
# !pip install matplotlib

# importing libraries
import matplotlib.pyplot as plt

# %%
#image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'
#image_path = 'E:\JamPython24\cv6\pexels-maxandrey-1366630.jpg'
image_path='/content/pexels-maxandrey-1366630.jpg'
image = plt.imread(image_path)
#image = plt.imread('pexels-maxandrey-1366630.jpg')

# %%
plt.imshow(image)

# %%
print(image)
# Out:
# [[[219 216 223]
#   [219 216 223]
#   [219 216 223]
#   ...
#   [220 217 224]
#   [220 217 224]
#   [219 216 223]]
#
#  [[219 216 223]
#   [219 216 223]
#   [218 215 222]
#   ...
#   [220 217 224]
#   [219 216 223]
#   [219 216 223]]
#
#  [[217 216 222]
#   [217 216 222]
#   [217 216 222]
#   ...
#   [218 217 223]
#   [218 217 223]
#   [217 216 222]]
#
#  ...
#
#  [[  0  18  12]
#   [  0  18  12]
#   [  0  18  12]
#   ...
#   [ 36  58  46]
#   [ 37  59  47]
#   [ 37  59  47]]
#
#  [[  0  18  12]
#   [  0  18  12]
#   [  0  18  12]
#   ...
#   [ 34  56  44]
#   [ 35  57  45]
#   [ 35  57  45]]
#
#  [[  0  18  12]
#   [  0  18  12]
#   [  0  18  12]
#   ...
#   [ 32  54  42]
#   [ 32  54  42]
#   [ 32  54  42]]]

# %%
print(image.shape)
# Out:
# (275, 183, 3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # OpenCV

# %% [markdown]
# If you do want to use google.colab features (like cv2_imshow) in Google Colab:
# You don’t need to install it—just run your code directly within a Google Colab notebook (which you can access at Google Colab).
# Summary:
# Local environment: Use cv2.imshow() or matplotlib to display images.
# Google Colab: google.colab.patches is already available, but cannot be installed outside of Colab.

# %% [markdown]
# ### FOR GOOGLE COLAB only ---  cv2_imshow(img)

# %%
#importing libraries
import cv2
from matplotlib import pyplot as plt # notice that we have imported pyplot differently
from google.colab.patches import cv2_imshow
#image_dir = 'berry-1.jpg' # relative path
image_dir = '/content/berry-2.jpg' # absolute path
#image_dir = 'E:\JamPython24\cv6\berry-2.jpg'
img = cv2.imread(image_dir)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=235x331>

# %% [markdown]
# #### For local drive only   ----   cv2.imshow('Image', img)

# %%
# import cv2

# # Provide the path to your image
# #image_path = 'path_to_your_image.jpg'
# #image_path = 'E:\JamPython24\cv6\berry-2.jpg'
# image_path = '/content/berry-2.jpg'
# # Load the image from the file
# img = cv2.imread(image_path)

# # Display the image in a window (with a window name, e.g., "Image")
# #cv2.imshow('Image', img)
# cv2.imshow('Image', img)

# # Wait for a key press to close the window
# cv2.waitKey(0)

# # Close all OpenCV windows
# cv2.destroyAllWindows()

# %% [markdown]
# #### For cv2 and matplotlib combindly

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image using OpenCV
image = cv2.imread('berry-2.jpg') # AS BRG

# Convert from BGR to RGB (Matplotlib uses RGB)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
#plt.imshow(image_rgb)
plt.imshow(image)#_rgb) # AS BRG

plt.axis('off')  # Hide axes for better presentation
plt.show()

# %%
# Load an image
#image_path = '/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/orange-1.jpg'  # Use your image path
image_path = 'orange-1.jpg'  # Use your image path
image = cv2.imread(image_path) # loading image using openCV

plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
# Display the image
plt.imshow(image_rgb) # showing image uisng matplotlib from previous cell 'berry-1.jpg'
#cv2_imshow(image)
plt.axis('off')  # Hide axes

#plt.show()

plt.subplot(1,2,2)

plt.imshow(image) # showing image uisng matplotlib from this cell 'orange-1.jpg'
#cv2_imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# ### ColorSpace conversion

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converting BGR to RGB
plt.imshow(image_rgb)

# %%
cv2_imshow(image_rgb) # explain this
# Out:
# <PIL.Image.Image image mode=RGB size=380x380>

# %%
cv2.imwrite('output_orange.jpg', image)
# Out:
# True

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
print(image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
image.shape
# Out:
# (380, 380, 3)

# %% [markdown]
# **Why the image looks different?**
#
# OpenCV uses BGR image format. So, when we read an image using cv2. imread() it interprets in BGR format by default.
#
# **OpenCV loads image in BGR and we are plotting RGB Image**
#
# **So we need to convert the BGR to RGB**

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converting BGR to RGB
plt.imshow(image_rgb)

# %%
show_colormap('viridis', 16, 'Viridis LUT')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-04720aade38b> in <cell line: 0>()
# ----> 1 show_colormap('viridis', 16, 'Viridis LUT')
#
# NameError: name 'show_colormap' is not defined
